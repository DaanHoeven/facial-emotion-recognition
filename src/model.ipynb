# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
import time
import os
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
import numpy as np

# %%
# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
TRAINING_DIR = '../images/train'
VALIDATION_DIR = '../images/validation'

# %%
# Data transformations
train_transforms = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),  # Convert to grayscale
    transforms.Resize((56, 56)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.RandomAffine(0, translate=(0.1, 0.1)),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])  # Normalize to [-1, 1]
])

val_transforms = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),  # Convert to grayscale
    transforms.Resize((56, 56)),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])  # Normalize to [-1, 1]
])

# %%
# Load datasets
train_dataset = datasets.ImageFolder(root=TRAINING_DIR, transform=train_transforms)
val_dataset = datasets.ImageFolder(root=VALIDATION_DIR, transform=val_transforms)

# %%
# Create data loaders
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4)

print(f"Number of training samples: {len(train_dataset)}")
print(f"Number of validation samples: {len(val_dataset)}")
print(f"Classes: {train_dataset.classes}")
# Out:
# Number of training samples: 56656
# Number of validation samples: 6955
# Classes: ['angry', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
# Define the model architecture
class FacialExpressionModel(nn.Module):
    def __init__(self, num_classes=6):
        super(FacialExpressionModel, self).__init__()
        
        # First Convolutional Block
        self.conv1 = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.25)
        )
        
        # Second Convolutional Block
        self.conv2 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=5, padding=2),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.25)
        )
        
        # Third Convolutional Block
        self.conv3 = nn.Sequential(
            nn.Conv2d(128, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.25)
        )
        
        # Fourth Convolutional Block
        self.conv4 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.25)
        )
        
        # Calculate the flattened size
        self.flat_features = 512 * 3 * 3
        
        # First Fully Connected Layer
        self.fc1 = nn.Sequential(
            nn.Linear(self.flat_features, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.25)
        )
        
        # Second Fully Connected Layer
        self.fc2 = nn.Sequential(
            nn.Linear(256, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Dropout(0.25)
        )
        
        # Output Layer
        self.output = nn.Linear(512, num_classes)
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = x.reshape(-1, self.flat_features)
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.output(x)
        return x

# %%
model = FacialExpressionModel().to(device)
print(model)
# Out:
# FacialExpressionModel(
#   (conv1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.25, inplace=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.25, inplace=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
# ...

# %%
# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
num_epochs = 500
scheduler = torch.optim.lr_scheduler.OneCycleLR(
    optimizer, 
    max_lr=0.001, 
    steps_per_epoch=len(train_loader), 
    epochs=num_epochs
)

# %%
# Function to save the model
def save_checkpoint(state, filename="model_weights.pth"):
    torch.save(state, filename)
    print(f"Checkpoint saved to {filename}")

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs):
    best_val_acc = 0.0
    model_save_path = f"../models/{num_epochs}_epochs_model.pth"
    best_model_path = "../snapshots/best_model.pth"

    os.makedirs("../models", exist_ok=True)
    os.makedirs("../snapshots", exist_ok=True)

    for epoch in range(num_epochs):
        start_time = time.time()
        
        # Training
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            scheduler.step()

            running_loss += loss.item() * inputs.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        train_loss = running_loss / len(train_loader.dataset)
        train_acc = 100. * correct / total

        # Validation
        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * inputs.size(0)
                _, predicted = outputs.max(1)
                total += labels.size(0)
                correct += predicted.eq(labels).sum().item()

        val_loss = val_loss / len(val_loader.dataset)
        val_acc = 100. * correct / total

        scheduler.step(val_acc)

        epoch_duration = time.time() - start_time

        print(f'Epoch {epoch+1}/{num_epochs} '
              f'(Duration: {epoch_duration:.2f}s) | '
              f'Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | '
              f'Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.2f}%')

        # Save best model
        if val_acc > best_val_acc:
            best_val_acc = val_acc

            # Save full model info to ../snapshots/
            torch.save({
                'epoch': epoch + 1,
                'state_dict': model.state_dict(),
                'best_val_acc': best_val_acc,
                'optimizer': optimizer.state_dict(),
            }, best_model_path)

            # Also save final weights to ../models/
            torch.save(model.state_dict(), model_save_path)

# %%
# Train the model
train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs)
# Out:
# c:\Users\erikh\OneDrive\Documenten\Daan\facial-emotion-recognition\venv\Lib\site-packages\torch\optim\lr_scheduler.py:243: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch 1/500 (Duration: 147.32s) | Train Loss: 1.7478 | Train Acc: 25.57% | Val Loss: 1.7580 | Val Acc: 28.32%
# Epoch 2/500 (Duration: 64.38s) | Train Loss: 1.6658 | Train Acc: 31.22% | Val Loss: 1.6863 | Val Acc: 34.91%
# Epoch 3/500 (Duration: 64.18s) | Train Loss: 1.5599 | Train Acc: 37.05% | Val Loss: 1.4735 | Val Acc: 41.44%
# ...

# %%
def load_best_model(model):
    checkpoint = torch.load('../snapshots/best_model.pth')
    model.load_state_dict(checkpoint['state_dict'])
    print(f"Loaded best model from epoch {checkpoint['epoch']} with validation accuracy: {checkpoint['best_val_acc']:.2f}%")
    return model

# %%
model = load_best_model(model)
# Out:
# Loaded best model from epoch 290 with validation accuracy: 85.98%

# %%
model.eval()
correct = 0
total = 0
all_preds = []
all_labels = []

class_correct = list(0. for i in range(6))
class_total = list(0. for i in range(6))

# %%
with torch.no_grad():
    for inputs, labels in val_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

        # Per-class accuracy
        c = (predicted == labels).squeeze()
        for i in range(len(labels)):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

# Overall accuracy
print(f'\n✅ Final Accuracy on the validation set: {100 * correct / total:.2f}%\n')

# Per-class accuracy
for i in range(len(train_dataset.classes)):
    print(f'📊 Accuracy of {train_dataset.classes[i]}: {100 * class_correct[i] / class_total[i]:.2f}%')

# Classification report
print("\n📄 Classification Report:")
print(classification_report(all_labels, all_preds, target_names=train_dataset.classes))

# Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=train_dataset.classes)
plt.figure(figsize=(8, 6))
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title("🧩 Confusion Matrix")
plt.show()
# Out:
# ✅ Final Accuracy on the validation set: 85.98%
#
# 📊 Accuracy of angry: 81.25%
# 📊 Accuracy of fear: 76.33%
# 📊 Accuracy of happy: 96.27%
# 📊 Accuracy of neutral: 83.14%
# 📊 Accuracy of sad: 80.16%
# 📊 Accuracy of surprise: 93.10%
#
# 📄 Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.84      0.81      0.82       960
#         fear       0.83      0.76      0.79      1018
#        happy       0.94      0.96      0.95      1825
#      neutral       0.82      0.83      0.83      1216
#          sad       0.78      0.80      0.79      1139
#     surprise       0.90      0.93      0.92       797
#
#     accuracy                           0.86      6955
#    macro avg       0.85      0.85      0.85      6955
# weighted avg       0.86      0.86      0.86      6955
# ...

# %%
# Load the best model from snapshots
checkpoint_path = "../snapshots/best_model.pth"
if os.path.exists(checkpoint_path):
    checkpoint = torch.load(checkpoint_path, map_location=device)
    model.load_state_dict(checkpoint['state_dict'])
    print(f"Loaded model with validation accuracy: {checkpoint['best_val_acc']:.2f}%")
else:
    # Alternative: load directly from the model weights file
    model_path = "../models/500_epochs_model.pth"
    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path, map_location=device))
        print(f"Loaded model weights from {model_path}")
    else:
        raise FileNotFoundError("Model weights not found!")

# Set model to evaluation mode and disable dropout
model.eval()
for m in model.modules():
    if isinstance(m, nn.Dropout):
        m.p = 0  # Disable dropout for visualization
# Out:
# Loaded model with validation accuracy: 85.98%

# %%
class_names = ['angry', 'fear', 'happy', 'sad', 'surprise']

# %%
# Create output directory
os.makedirs("../expression_prototypes", exist_ok=True)

# Function to generate prototype images with enhanced interpretability
def generate_expression_prototype(model, class_idx, img_size=56, iterations=800, lr=0.05, 
                                  l2_strength=1e-4, tv_strength=1e-3, blur_every=10, blur_sigma=0.5,
                                  face_prior_strength=1e-2):
    """
    Generate a prototype image for a specific facial expression class
    with improved regularization and interpretability.
    """
    # Create a random noise image, initialized with a face-like oval
    img = torch.randn(1, 1, img_size, img_size, requires_grad=True, device=device)
    
    # Create a face-like oval prior to help with interpretability
    # This creates a basic oval mask that encourages the optimization to focus on face-like regions
    y, x = np.ogrid[-img_size//2:img_size//2, -img_size//2:img_size//2]
    face_mask = ((x / (img_size * 0.3)) ** 2 + (y / (img_size * 0.4)) ** 2) <= 1
    face_prior = np.zeros((img_size, img_size))
    face_prior[face_mask] = 1
    
    # Add some basic facial features (eyes, nose, mouth positions) to guide the optimization
    # Eyes
    eye_y = int(img_size * 0.35)
    left_eye_x = int(img_size * 0.35)
    right_eye_x = int(img_size * 0.65)
    eye_size = int(img_size * 0.08)
    face_prior[eye_y-eye_size:eye_y+eye_size, left_eye_x-eye_size:left_eye_x+eye_size] = 0.8
    face_prior[eye_y-eye_size:eye_y+eye_size, right_eye_x-eye_size:right_eye_x+eye_size] = 0.8
    
    # Nose
    nose_y = int(img_size * 0.5)
    nose_x = int(img_size * 0.5)
    nose_size = int(img_size * 0.06)
    face_prior[nose_y-nose_size:nose_y+nose_size, nose_x-nose_size:nose_x+nose_size] = 0.7
    
    # Mouth
    mouth_y = int(img_size * 0.7)
    mouth_width = int(img_size * 0.4)
    mouth_height = int(img_size * 0.1)
    face_prior[mouth_y-mouth_height:mouth_y+mouth_height, 
               nose_x-mouth_width//2:nose_x+mouth_width//2] = 0.9
    
    # Convert to tensor and move to device
    face_prior = torch.tensor(face_prior, dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(0)
    
    # Define optimizer for the image
    optimizer = optim.Adam([img], lr=lr)
    
    # Track the progress
    progress_images = []
    
    for i in range(iterations):
        optimizer.zero_grad()
        
        # Normalize the image to match preprocessing
        normalized_img = transforms.Normalize([0.5], [0.5])(img.clone())
        
        # Forward pass
        output = model(normalized_img)
        
        # Calculate loss (negative because we want to maximize the target class score)
        class_score = output[0, class_idx]
        
        # L2 regularization to prevent extreme pixel values
        l2_reg = l2_strength * torch.sum(img ** 2)
        
        # Total variation regularization for smoothness
        tv_reg = tv_strength * (
            torch.sum(torch.abs(img[:, :, :, :-1] - img[:, :, :, 1:])) + 
            torch.sum(torch.abs(img[:, :, :-1, :] - img[:, :, 1:, :]))
        )
        
        # Face prior loss to encourage face-like structure
        face_prior_loss = face_prior_strength * torch.sum((img - face_prior) ** 2 * face_prior)
        
        # Combine all loss components
        loss = -class_score + l2_reg + tv_reg + face_prior_loss
        
        # Backward pass
        loss.backward()
        
        # Update the image
        optimizer.step()
        
        # Clip the image values to stay within a reasonable range
        with torch.no_grad():
            img.clamp_(-1.5, 1.5)
        
        # Apply Gaussian blur periodically to help with smoothness
        if i % blur_every == 0 and i > 0:
            with torch.no_grad():
                img_np = img.cpu().detach().numpy()[0, 0]
                img_np = gaussian_filter(img_np, sigma=blur_sigma)
                img.data = torch.tensor(img_np, device=device).unsqueeze(0).unsqueeze(0)
        
        # Save progress every 100 iterations
        if i % 100 == 0 or i == iterations - 1:
            print(f"Iteration {i}: Class score = {class_score.item():.4f}")
            progress_images.append(img.clone().detach())
    
    return progress_images

# %%
# Enhanced visualization with high contrast and facial feature highlighting
def enhance_visualization(img_tensor):
    """Enhance the visibility of facial features in the generated prototype"""
    # Convert to numpy array
    img_np = img_tensor.cpu().detach().numpy()[0, 0]
    
    # Apply histogram equalization for better contrast
    img_np = (img_np - img_np.min()) / (img_np.max() - img_np.min())
    
    # Apply adaptive histogram equalization to enhance local features
    img_np = np.power(img_np, 0.8)  # Gamma correction to enhance mid-tones
    
    # Apply additional edge enhancement
    from scipy import ndimage
    edge_enhance = ndimage.gaussian_gradient_magnitude(img_np, sigma=1.0)
    img_np = np.clip(img_np + 0.2 * edge_enhance, 0, 1)
    
    return img_np

# Generate prototypes for each facial expression class
print("Generating prototype images for each facial expression...")
all_prototypes = []

for class_idx, class_name in enumerate(class_names):
    print(f"\nGenerating prototype for class: {class_name}")
    prototype_images = generate_expression_prototype(
        model, class_idx, iterations=600, 
        lr=0.08, l2_strength=1e-4, tv_strength=5e-4,
        blur_every=20, blur_sigma=0.8
    )
    all_prototypes.append(prototype_images[-1])  # Save the final image

# Plot all prototypes in a grid with enhancements
plt.figure(figsize=(15, 8))
for i, (img, class_name) in enumerate(zip(all_prototypes, class_names)):
    plt.subplot(2, 3, i+1)
    
    # Enhance the visualization
    img_enhanced = enhance_visualization(img)
    
    plt.imshow(img_enhanced, cmap='gray')
    plt.title(class_name.capitalize())
    plt.axis('off')
    
    # Save individual image
    plt.figure(figsize=(6, 6))
    plt.imshow(img_enhanced, cmap='gray')
    plt.title(f"{class_name.capitalize()} Expression Prototype")
    plt.axis('off')
    plt.tight_layout()
    plt.savefig(f"../expression_prototypes/{class_name}_prototype.png", dpi=300, bbox_inches='tight')
    plt.close()

plt.tight_layout()
plt.savefig("../expression_prototypes/all_expressions.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Generating prototype images for each facial expression...
#
# Generating prototype for class: angry
# Iteration 0: Class score = 0.9398
# Iteration 100: Class score = 193.9936
# Iteration 200: Class score = 207.9612
# Iteration 300: Class score = 211.1044
# Iteration 400: Class score = 212.4524
# Iteration 500: Class score = 211.3994
# Iteration 599: Class score = 209.9555
#
# Generating prototype for class: fear
# Iteration 0: Class score = -4.5726
# Iteration 100: Class score = 144.9791
# Iteration 200: Class score = 173.0518
# Iteration 300: Class score = 181.1581
# Iteration 400: Class score = 180.6038
# Iteration 500: Class score = 183.3236
# Iteration 599: Class score = 183.7927
#
# Generating prototype for class: happy
# Iteration 0: Class score = -27.0956
# Iteration 100: Class score = 162.7223
# Iteration 200: Class score = 187.2193
# Iteration 300: Class score = 202.7378
# Iteration 400: Class score = 208.2731
# Iteration 500: Class score = 216.1610
# ...

# %%
def visualize_expression_optimization(
    expression_name,
    class_names,
    model,
    iterations=600,
    lr=0.08,
    l2_strength=1e-4,
    tv_strength=5e-4,
    save_path="../expression_prototypes"
):
    print(f"\nCreating visualization of the optimization process for '{expression_name}' expression...")

    if expression_name not in class_names:
        print(f"Error: '{expression_name}' not found in class names.")
        return

    class_idx = class_names.index(expression_name)
    progress_images = generate_expression_prototype(
        model, class_idx,
        iterations=iterations,
        lr=lr,
        l2_strength=l2_strength,
        tv_strength=tv_strength
    )

    if progress_images and len(progress_images) > 0:
        plt.figure(figsize=(15, 3))
        num_steps = min(8, len(progress_images))
        step_indices = np.linspace(0, len(progress_images)-1, num_steps).astype(int)

        for i, step_idx in enumerate(step_indices):
            plt.subplot(1, num_steps, i+1)
            img_step = progress_images[step_idx]
            img_enhanced = enhance_visualization(img_step)
            plt.imshow(img_enhanced, cmap='gray')
            actual_iteration = step_idx * iterations // len(progress_images)
            plt.title(f"Step {actual_iteration}")
            plt.axis('off')

        plt.tight_layout()
        os.makedirs(save_path, exist_ok=True)
        save_file = os.path.join(save_path, f"{expression_name}_optimization_progress.png")
        plt.savefig(save_file, dpi=300, bbox_inches='tight')
        plt.show()
    else:
        print(f"Warning: No progress images were generated for '{expression_name}' expression.")

# %%
visualize_expression_optimization("angry", class_names, model)
# Out:
# Creating visualization of the optimization process for 'angry' expression...
# Iteration 0: Class score = 0.4023
# Iteration 100: Class score = 180.4553
# Iteration 200: Class score = 208.1840
# Iteration 300: Class score = 229.1177
# Iteration 400: Class score = 246.0601
# Iteration 500: Class score = 249.6130
# Iteration 600: Class score = 250.3549
# Iteration 700: Class score = 249.6037
# Iteration 800: Class score = 251.5121
# Iteration 900: Class score = 250.4778
# Iteration 1000: Class score = 251.8748
# Iteration 1100: Class score = 252.8817
# Iteration 1200: Class score = 255.2502
# Iteration 1300: Class score = 254.9851
# Iteration 1400: Class score = 255.8227
# Iteration 1500: Class score = 255.1863
# Iteration 1600: Class score = 255.5853
# Iteration 1700: Class score = 255.5976
# Iteration 1800: Class score = 255.7183
# Iteration 1900: Class score = 255.9480
# Iteration 2000: Class score = 255.1326
# Iteration 2100: Class score = 254.5616
# ...
